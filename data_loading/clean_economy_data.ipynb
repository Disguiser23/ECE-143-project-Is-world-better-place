# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Format 1: gdp, annual-work-hours

# %%
df = pd.read_csv('../data/economy/UNdata_GDP.csv')
df2 = pd.read_csv('../data/economy/annual-work-hours.csv')
df2
#df
# Out:
#      COUNTRY    Country EMPSTAT     Employment status FREQUENCY Frequency  \
# 0        AUS  Australia      TE      Total employment         A    Annual
# 1        AUS  Australia      TE      Total employment         A    Annual
# 2        AUS  Australia      TE      Total employment         A    Annual
# 3        AUS  Australia      TE      Total employment         A    Annual
# 4        AUS  Australia      TE      Total employment         A    Annual
# ...      ...        ...     ...                   ...       ...       ...
# 1468     ISR     Israel      DE  Dependent employment         A    Annual
# 1469     ISR     Israel      DE  Dependent employment         A    Annual
# 1470     ISR     Israel      DE  Dependent employment         A    Annual
# 1471     ISR     Israel      DE  Dependent employment         A    Annual
# 1472     ISR     Israel      DE  Dependent employment         A    Annual
#
#       TIME  Time Unit Code   Unit  PowerCode Code PowerCode  \
# 0     2000  2000      HOUR  Hours               0     Units
# 1     2001  2001      HOUR  Hours               0     Units
# 2     2002  2002      HOUR  Hours               0     Units
# 3     2003  2003      HOUR  Hours               0     Units
# 4     2004  2004      HOUR  Hours               0     Units
# ...    ...   ...       ...    ...             ...       ...
# 1468  2014  2014      HOUR  Hours               0     Units
# 1469  2015  2015      HOUR  Hours               0     Units
# 1470  2016  2016      HOUR  Hours               0     Units
# 1471  2017  2017      HOUR  Hours               0     Units
# 1472  2018  2018      HOUR  Hours               0     Units
#
#       Reference Period Code  Reference Period   Value  Flag Codes  Flags
# 0                       NaN               NaN  1831.0         NaN    NaN
# 1                       NaN               NaN  1814.0         NaN    NaN
# 2                       NaN               NaN  1794.0         NaN    NaN
# 3                       NaN               NaN  1798.0         NaN    NaN
# 4                       NaN               NaN  1801.0         NaN    NaN
# ...                     ...               ...     ...         ...    ...
# 1468                    NaN               NaN  1901.0         NaN    NaN
# 1469                    NaN               NaN  1900.0         NaN    NaN
# 1470                    NaN               NaN  1923.0         NaN    NaN
# 1471                    NaN               NaN  1924.0         NaN    NaN
# 1472                    NaN               NaN  1919.0         NaN    NaN
#
# [1473 rows x 17 columns]

# %% [markdown]
# ### Cleaned Data (gdp)
# index: Country Names (str)
#
# columns: year of data (int)

# %%
# read csv as DataFrame data structure
df = pd.read_csv('../data/economy/UNdata_GDP.csv')

# countries: an 1D np array of all the countries (str)
countries = df['Country or Area'].drop_duplicates().values

# years: an 1D np array of all the years (int)
years = np.flip(df['Year'].drop_duplicates().values)

# GDP: an 1D np array of GDP values (int) of each countries each year
GDP = df['Value'].values

# n_countries, n_years are the # of countries and years
n_co = countries.shape[0]
n_yr = years.shape[0]

# create a DataFrame with all values as nan
dummy = np.zeros([n_co, n_yr])
dummy = np.nan
gdp_df = pd.DataFrame(dummy, index = countries, columns=years)

# assigning the correct GDP values to the DF
for i in range(0, GDP.shape[0]):
    i_year = df['Year'].values[i]
    i_country = df['Country or Area'].values[i]
    gdp_df[i_year][i_country] = GDP[i]
    
#print(newdf.index)

gdp_df.to_csv('../data/economy/cleaned_data/cleanedGDP.csv', index = True)

#gdp_df

# %% [markdown]
# #### Clean annual work hours

# %%
# read csv as DataFrame data structure
df = pd.read_csv('../data/economy/annual-work-hours.csv')

# countries: an 1D np array of all the countries (str)
countries = df['Country'].drop_duplicates().values

# years: an 1D np array of all the years (int)
years = (df['Time'].drop_duplicates().values)

# GDP: an 1D np array of GDP values (int) of each countries each year
GDP = df['Value'].values

# n_countries, n_years are the # of countries and years
n_co = countries.shape[0]
n_yr = years.shape[0]

# create a DataFrame with all values as nan
dummy = np.zeros([n_co, n_yr])
dummy = np.nan
workhrs_df = pd.DataFrame(dummy, index = countries, columns=years)

# assigning the correct GDP values to the DF
for i in range(0, GDP.shape[0]):
    i_year = df['Time'].values[i]
    i_country = df['Country'].values[i]
    workhrs_df[i_year][i_country] = GDP[i]
    
workhrs_df.to_csv('../data/economy/cleaned_data/cleaned_annual_work_hrs.csv', index = True)
workhrs_df
# Out:
#                       2000    2001    2002    2003    2004    2005    2006  \
# Australia           1807.0  1788.0  1772.0  1774.0  1787.0  1788.0  1785.0
# Austria             1675.0  1663.0  1661.0  1652.0  1655.0  1632.0  1617.0
# Belgium             1589.0  1581.0  1594.0  1598.0  1588.0  1578.0  1592.0
# Canada              1787.0  1774.0  1755.0  1745.0  1755.0  1745.0  1744.0
# Czech Republic      1896.0  1818.0  1817.0  1806.0  1817.0  1817.0  1799.0
# Denmark             1466.0  1469.0  1463.0  1458.0  1458.0  1451.0  1456.0
# Finland             1650.0  1636.0  1628.0  1623.0  1624.0  1613.0  1608.0
# France              1558.0  1538.0  1504.0  1507.0  1531.0  1532.0  1515.0
# Germany             1465.9  1458.2  1448.9  1443.4  1442.6  1432.4  1453.2
# Greece              2017.0  2011.0  2003.0  2001.0  1993.0  2044.0  2034.0
# Hungary             1932.4  1897.8  1883.6  1856.3  1858.6  1834.1  1813.9
# Iceland             1696.0  1707.0  1672.0  1639.0  1645.0  1637.0  1627.0
# Ireland             1933.0  1924.0  1904.0  1887.0  1875.0  1883.0  1879.0
# Italy               1696.0  1685.0  1672.0  1653.0  1657.0  1646.0  1652.0
# Japan               1821.0  1809.0  1798.0  1799.0  1787.0  1775.0  1784.0
# Korea                  NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Luxembourg          1602.0  1586.0  1581.0  1579.0  1578.0  1550.0  1552.0
# Mexico              2174.0  2146.0  2196.0  2143.0  2123.0  2105.0  2067.0
# Netherlands         1464.0  1454.0  1436.0  1428.0  1448.0  1434.0  1430.0
# New Zealand         1836.0  1825.0  1826.0  1823.0  1830.0  1815.0  1795.0
# Hungary             1748.6  1745.9  1760.2  1747.4  1728.9  1725.2
# Iceland             1488.0  1486.0  1474.0  1464.0  1449.0  1454.0
# Ireland             1757.0  1771.0  1763.0  1775.0  1785.0  1772.0
# Italy               1566.0  1570.0  1581.0  1581.0  1586.0  1583.0
# Japan               1729.0  1719.0  1714.0  1709.0  1680.0  1644.0
# Korea               2076.0  2083.0  2068.0  2018.0  1993.0  1967.0
# Luxembourg          1506.0  1514.0  1513.0  1507.0  1506.0  1506.0
# Mexico              2134.0  2140.0  2146.0  2148.0  2149.0  2137.0
# Netherlands         1426.0  1426.0  1437.0  1435.0  1431.0  1434.0
# New Zealand         1757.0  1751.0  1751.0  1752.0  1754.0  1779.0
# Norway              1371.0  1374.0  1378.0  1364.0  1366.0  1368.0
# Poland              1822.0  1829.0  1831.0  1812.0  1787.0  1806.0
# Portugal            1725.0  1732.0  1737.0  1727.0  1722.0  1719.0
# Slovak Republic     1760.0  1754.0  1740.0  1714.0  1704.0  1695.0
# Spain               1690.6  1694.2  1701.5  1689.5  1695.5  1686.0
# Sweden              1416.0  1418.0  1432.0  1419.0  1419.0  1406.0
# Switzerland         1564.0  1580.0  1581.0  1564.0  1552.0  1556.9
# Turkey                 NaN     NaN     NaN     NaN     NaN     NaN
# United Kingdom      1543.0  1527.0  1541.0  1540.0  1535.0  1538.0
# United States       1782.0  1783.0  1778.0  1778.0  1783.0  1779.0
# OECD countries      1746.0  1745.0  1745.0  1739.0  1735.0  1726.0
# Israel              1901.0  1900.0  1923.0  1924.0  1919.0  1898.1
# Chile               1990.0  1988.0  1974.0  1954.0  1940.6  1914.4
# Slovenia            1681.8  1687.3  1652.4  1621.5  1598.7  1592.9
# Estonia             1771.0  1763.0  1767.0  1768.0  1724.0  1711.0
# Russian Federation  1985.0  1978.0  1974.0  1979.0  1970.0  1965.0
# Lithuania           1620.0  1643.0  1664.0  1627.0  1634.0  1635.0
# Latvia              1726.0  1694.0  1694.0  1680.0  1692.0  1661.0
# Costa Rica          2121.7  2148.2  2204.7  2178.9  2121.0  2059.6

# %% [markdown]
# ### Format 2 (using format 1 from health)

# %%
data_economy = '../data/economy/'
data_list = ['Employment to population ratio (% ages 15 and older).csv',
            'Labour force participation rate (% ages 15 and older).csv',
            'Unemployment, total (% of labour force).csv'
            ]
# country count in each list
country = [19, 19, 19]

# %%
for c, d in zip(country, data_list):
    df = pd.read_csv(data_economy + d,skiprows=1)

    df.drop(columns=['HDI Rank (2018)'], inplace = True)
    df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

    # Keep only the country data
    df.drop(df.tail(c).index,inplace=True)
    df.replace('..', np.nan,inplace=True)

    df.set_index("Country", inplace = True)
    df.astype('float64').dtypes
    df = df.apply(pd.to_numeric, errors='ignore')

    df.to_csv(data_economy +'cleaned_data/cleaned_'+ d)
