# %%
import health
import economy
import environment
# Why inline?????
# %matplotlib inline

# %%
health.run()
# Out:
# D:\Application\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Application\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Application\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Application\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# ...

# %%
economy.run()
# Out:
# D:\Application\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Application\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Application\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Application\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# ...

# %%
environment.run()
