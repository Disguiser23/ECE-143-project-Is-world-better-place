# %%
import health
import economy
#import environment
# Why inline?????
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
health.run()

# %%
economy.run()

# %%
environment.plot_natural_disaster_prediction(file_name = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3ba46babe52f> in <module>
# ----> 1 environment.plot_natural_disaster_prediction(file_name = None)
#
# NameError: name 'environment' is not defined

# %%
environment.plot_predict_co2_continent(year_start = 1900, year_end = 2018, file_name = None)

# %%
environment.plot_co2_world_map(year_start=1980, year_end=2018)

# %%
environment.plot_predict_co2_continent_person(year_start=1950,
                                      year_end=2018,
                                      file_name=None)

# %%
environment.plot_world_co2_disaster(year_start=1900, year_end=2018)

# %%
import world_overall
