# %%
import pandas as pd
import numpy as np
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
from read_disaster import fig_total_natural_disaster
fig = fig_total_natural_disaster()
fig.show()

# %%
from read_disaster import fig_natural_disaster
fig = fig_natural_disaster()
fig.show()

# %%
from read_co2 import fig_co2_trans
fig = fig_co2_trans()
fig.show()

# %%
from read_co2 import fig_sunburst_co2_country
curr_year = 2018
fig = fig_sunburst_co2_country(curr_year)
fig.show()

# %%
from read_co2 import fig_map_co2_country
fig = fig_map_co2_country(year_start=1998, year_end=2018)
fig.show()

# %%
warnings.filterwarnings('ignore')
from read_co2 import plot_predict_co2_continent
plot_predict_co2_continent(year_start = 1900, year_end = 2018, file_name = None)

# %%
warnings.filterwarnings('ignore')
from envi_merge import plot_predict_co2_continent_person
plot_predict_co2_continent_person(year_start=1950,
                                      year_end=2018,
                                      file_name=None)

# %%
from envi_merge import fig_world_co2_disaster
fig = fig_world_co2_disaster(year_start=1900, year_end=2018)
fig.show()
